# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import os

# %%
import nvidia_smi

nvidia_smi.nvmlInit()
deviceCount = nvidia_smi.nvmlDeviceGetCount()
freem = []
for i in range(deviceCount):
    handle = nvidia_smi.nvmlDeviceGetHandleByIndex(i)
    info = nvidia_smi.nvmlDeviceGetMemoryInfo(handle)
    freem.append(100*info.free/info.total)
nvidia_smi.nvmlShutdown()
print(freem)
# Out:
# [98.6397777234978, 98.68812082722684]

# %% [markdown]
# # 1. 데이터 로드

# %%
from langchain.document_loaders import CSVLoader
from langchain.document_loaders import PyPDFLoader
from langchain.document_loaders import DirectoryLoader
from langchain.text_splitter import CharacterTextSplitter, RecursiveCharacterTextSplitter

# %%
# 사용 문서명 입력
docs_nm = './rag_data/rerere_answer_summary_by_chatgpt.csv'
train_loader = CSVLoader(docs_nm, 'contents', ['idx'])
documents = train_loader.load()

# %% [markdown]
# &#10004; 블로그 컨텐츠 추가

# %%
docs_nm = './rag_data/blog_summary_final.csv'
blog_loader = CSVLoader(docs_nm)
blog_documents = blog_loader.load()

documents = documents + blog_documents

# %% [markdown]
# # 2. RAG

# %%
import os
import torch
from datasets import load_dataset
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    BitsAndBytesConfig,
    TrainingArguments,
    pipeline,
    logging,
)
from langchain import HuggingFacePipeline
from langchain.embeddings import HuggingFaceEmbeddings
from langchain.vectorstores import FAISS
from langchain.chains import ConversationalRetrievalChain
from langchain.chains import RetrievalQA
from peft import LoraConfig, PeftModel

# %% [markdown]
# ## 2.1 모델 로드

# %%
model_nm = "Orion-14B-Chat-RAG-papering"

# %%
base_model = "jylee420/Orion-14B-Chat-RAG-papering"

# %%
# 4-bit quantization configuration
compute_dtype = getattr(torch, "float16")
use_4bit=True

quant_config = BitsAndBytesConfig(
    load_in_4bit=use_4bit,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=compute_dtype,
    bnb_4bit_use_double_quant=False,
)

# %%
# Check GPU compatibility with bfloat16
if compute_dtype == torch.float16 and use_4bit:
    major, _ = torch.cuda.get_device_capability()
    if major >= 8:
        print("=" * 80)
        print("Your GPU supports bfloat16: accelerate training with bf16=True")
        print("=" * 80)
# Out:
# ================================================================================
# Your GPU supports bfloat16: accelerate training with bf16=True
# ================================================================================

# %%
# Load LLaMA tokenizer
tokenizer = AutoTokenizer.from_pretrained(base_model, trust_remote_code=True)
print(tokenizer.cls_token, tokenizer.sep_token, tokenizer.pad_token, tokenizer.unk_token)
print(tokenizer.cls_token_id, tokenizer.sep_token_id, tokenizer.pad_token_id, tokenizer.unk_token_id)

# tokenizer.pad_token = tokenizer.eos_token # <eos> 토큰 안나오는 문제 원인일 수 있음
tokenizer.pad_token = tokenizer.unk_token
tokenizer.padding_side = "right" # Fix weird overflow issue with fp16 training
# Out:
# None None <unk> <unk>
# None None 0 0

# %%
# %%time
model = AutoModelForCausalLM.from_pretrained(
                base_model,
                quantization_config=quant_config,
                device_map="auto",
                torch_dtype=torch.float16,
                trust_remote_code=True,
)
# Out:
# Using `is_flash_attn_available` is deprecated and will be removed in v4.38. Please use `is_flash_attn_2_available` instead.
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# /usr/local/lib/python3.8/dist-packages/torch/_utils.py:831: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# CPU times: user 50.6 s, sys: 13.7 s, total: 1min 4s
# Wall time: 12.1 s

# %%
pipe = pipeline(task="text-generation",
                model=model,
                tokenizer=tokenizer,
                max_length=3000,
                device_map="auto",
                torch_dtype=torch.float16
               )

# %%
llm = HuggingFacePipeline(
    pipeline=pipe,
    model_kwargs={'temperature':0.1, 'max_length':3000}
)

# %% [markdown]
# ## 2.2 Retriever

# %%
#load Embedding model
# embedding_model = "jhgan/ko-sbert-nli"
embedding_model = "BAAI/bge-m3" # 정연전임님 임베딩 모델
model_kwargs={'device':'cpu'}
encode_kwargs = {'normalize_embeddings':False}

embeddings = HuggingFaceEmbeddings(
    model_name=embedding_model,
    model_kwargs=model_kwargs,
    encode_kwargs=encode_kwargs
)

# %%
# %%time
vectordb = FAISS.from_documents(
    documents = documents,
    embedding = embeddings,
)
# Out:
# CPU times: user 25min 18s, sys: 6min 43s, total: 32min 1s
# Wall time: 2min 3s

# %% [markdown]
# #### multi query retriever

# %%
from langchain.prompts import PromptTemplate
from langchain.retrievers.multi_query import MultiQueryRetriever
from langchain.chains import LLMChain

# %%
# Set logging for the queries
import logging

logging.basicConfig()
logging.getLogger("langchain.retrievers.multi_query").setLevel(logging.INFO)

# %% [markdown]
# &#10004; 다중질문 처리하는 prompttemplate 추가. inference할 때 prompt 추가하는 것 대신 아래 항목에서 제어하면 됨

# %%
QUERY_PROMPT = PromptTemplate(
    input_variables=['question'],
    template = """
        Your task is to split multiple querys to single query that aim to answer all user's questions 
        The user questions are focused on interior, papering, and related techniques.
        Each query Must tackle the question from a different viewpoint, we want to get a variety of RELEVANT search results.
        Provide these alternative questions seperated by newlines.
        Original question : {question}
    """
)

# %%
# 선택할 관련 문서 개수 정하기
# search_type = "similarity_score" 가 기본버전
retriever = vectordb.as_retriever(search_type="mmr", # "similarity_score
                                  search_kwargs={"k":3, 'fetch_k':3})

# %% [markdown]
# &#10004; MultiqueryRetriever을 한 번 더 선언함

# %%
retriever_from_llm = MultiQueryRetriever.from_llm(
    retriever = retriever,
    llm = llm,
    prompt = QUERY_PROMPT,
)

# %% [markdown]
# &#10004; chain 안의 retriever를 retriever_from_llm으로 변경해주어야 함

# %%
# Chaining a pipeline
chain = ConversationalRetrievalChain.from_llm(
    llm=llm,
    retriever=retriever_from_llm,
    chain_type='stuff',
    # combine_docs_chain_kwargs={'prompt': QUERY_PROMPT},
)

# %% [markdown]
# # 3. Evaluation

# %%
def rag_answer(query) :
    chat_history = []
    result = chain({"question": query, "chat_history": chat_history})
    return result['answer']

# %% [markdown]
# &#10004; rag_answer 함수를 실행시키면 사용자 질문이 어떤 다양한 쿼리로 변형되는지 확인 가능함

# %%
question = "유성페인트를 사용하는 것에 대한 부작용이 있을까요? 또한, 페인트가 남으면 어디에 보관하는 게 좋을까요?"

# %%
rag_answer(question)
# Out:
# /usr/local/lib/python3.8/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 유성페인트 사용시 부작용은 무엇인가요?', '        2. 유성페인트를 사용하지 않는다면 어떤 대안이 있을까요?', '        3. 유성페인트를 사용한 후 남은 페인트는 어떻게 처리해야 할까요?', '        4. 유성페인트를 사용하기 전 주의사항은 무엇인가요?', '        5. 유성페인트를 사용한 후 냄새가 오래가는 경우가 있는데, 왜 그런가요?']
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ' 유성페인트를 사용할 때 발생할 수 있는 부작용으로는 인체에 유해한 영향, 강한 냄새, 건조 시간이 길어지는 것 등이 있습니다. 또한, 환경 오염, 유지보수의 어려움, 비용 증가 등이 있습니다. 따라서, 유성페인트를 사용할 때는 안전하고 적절한 환경에서 사용하고, 꼭 필요한 경우에만 사용하는 것이 좋습니다. 페인트가 남았을 때는 깨끗한 컨테이너에 보관하고, 날짜와 종류를 표시하는 것이 좋습니다.'

# %%
test = pd.read_csv('./dacon_result/test.csv')
test.head(2)
# Out:
#          id                                                 질문
# 0  TEST_000  방청 페인트의 종류에는 어떤 것들이 있는지 알고 계신가요? 또한, 원목사이딩을 사용...
# 1  TEST_001            도배지에 녹은 자국이 발생하는 주된 원인과 그 해결 방법은 무엇인가요?

# %%
# %%time
result = []
docs_lst = []
for q in tqdm(test['질문']) :
    result.append(rag_answer(q))
    docs_lst.append(retriever_from_llm.get_relevant_documents(query=q))
# Out:
#   0%|                                                                                                                                                           | 0/130 [00:00<?, ?it/s]Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 방청 페인트의 종류와 특징은 무엇인가요?', '        2. 원목사이딩을 사용하면 어떤 문제가 발생할 수 있나요?', '        3. 방청 페인트를 선택할 때 고려해야 할 사항은 무엇인가요?', '        4. 원목사이딩의 장단점은 무엇인가요?']
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 방청 페인트의 종류에는 어떤 것들이 있는지 알고 계신가요?', '        2. 원목사이딩을 사용하는 것에 어떤 장점과 단점이 있을까요?']
#   1%|█▏                                                                                                                                                 | 1/130 [00:07<15:16,  7.10s/it]Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 도배지에 녹이 생기는 주된 원인은 무엇인가요?', '        2. 도배지에 녹이 생겼을 때 어떻게 해야 하나요?', '        3. 도배지에 녹이 생긴 경우, 어떤 해결책이 있나요?', '        4. 도배지에 녹이 생겼을 때, 어떤 방법을 시도해 볼 수 있나요?', '        5. 도배지에 녹이 생겼을 때, 어떤 조치를 취해야 하나요?']
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 도배지에 녹이 발생하는 주된 원인은 무엇인가요?', '        2. 도배지에 녹이 발생했을 때 어떻게 처리해야 하나요?', '        3. 도배지에 녹이 발생하는 것을 방지하려면 어떻게 해야 하나요?']
#   2%|██▎                                                                                                                                                | 2/130 [00:14<15:59,  7.49s/it]Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 큐블럭의 단점은 무엇인가요?', '        2. 압출법 단열판의 장점은 무엇인가요?', '        3. 큐블럭과 압축법 단열판 각각의 장단점을 비교해주세요.']
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 큐블럭의 단점은 무엇인가요?', '        2. 압축법 단열재를 사용하는 것에 대한 장점은 무엇인가요?', '        3. 큐블럭과 압축법 단열재 중 어떤 것이 더 나은 선택인가요? ', '        4. 큐블럭과 압축법 단열재의 장단점을 비교해주세요.']
#   2%|███▍                                                                                                                                               | 3/130 [00:22<15:36,  7.38s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 철골 구조를 사용하는 고층 건물에서 단열 효과를 높이기 위한 시공 방법은 무엇인가요?', '        2. 고층 건물에서 철골 구조를 사용하면서 단열 효과를 높이기 위해 어떤 시공 방법을 사용할 수 있나요?', '        3. 철골 구조를 사용하는 고층 빌딩에서 단열 효과를 높이기 위한 시공 방법에는 어떤 것이 있나요?', '        4. 철골 구조를 사용하는 고층 빌딩에서 단열 효과를 높이기 위해 어떤 시공 방법을 고려할 수 있나요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 철골구조를 사용하는 고층 건물에서, 단열 효과를 높이기 위한 시공 방법은 무엇이 있을까요?', '        2. 철골구조를 사용하는 고층 건물에서, 단열 효과를 높이기 위한 시공 방법에는 어떤 것이 있나요?', '        3. 철골구조를 사용하는 고층 건물에서, 단열 효과를 높이기 위한 시공 방법을 알고 싶습니다.', '        4. 철골구조를 사용하는 고층 건물에서, 단열 효과를 높이기 위한 시공 기술은 무엇이 있을까요?', '        5. 철골구조를 사용하는 고층 건물에서, 단열 효과를 높이기 위한 시공 기법은 어떤 것이 있나요?']
#   3%|████▌                                                                                                                                              | 4/130 [00:30<16:30,  7.86s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 도배지를 완전히 말리기 위해 몇 주를 기다려야 하나요?', '        2. 도배지를 완전히 마르게 만드는 데 걸리는 시간은 얼마나 되나요?', '        3. 도배지를 완전히 건조시키는 데 필요한 기간은 얼마인가요?', '        4. 도배지를 완전히 건조시키기 위해 몇 주를 기다려야 하나요?', '        5. 도배지를 완전히 건조시키는 데 필요한 시간을 알려주세요.']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 도배지를 완전히 말리기 위해 몇 주를 기다려야 하나요?', '        2. 도배지를 완전히 마르게 만드는 데 걸리는 시간은 얼마나 되나요?', '        3. 도배지를 완전히 건조시키는 데 필요한 기간은 얼마인가요?', '        4. 도배지를 완전히 건조시키기 위해 몇 주를 기다려야 하나요?', '        5. 도배지를 완전히 건조시키기 위해 얼마나 많은 시간을 기다려야 하나요?']
#   4%|█████▋                                                                                                                                             | 5/130 [00:38<16:09,  7.75s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 철근철골콘크리트 구조가 적용된 건물의 장점을 알려주세요.', '        2. 철근철골콘크리트 구조가 적용된 건물의 단점을 알려주세요.', '        3. 철근철골콘크리트 구조가 적용된 건물의 특징을 알려주세요.', '        4. 철근철골콘크리트 구조가 적용된 건물의 장단점을 비교해주세요.']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 철근철골콘크리트 구조가 적용된 건물의 장점과 단점은 무엇인가요?', '        2. 철근철골콘크리트 구조를 사용한 건물은 어떤 특징이 있으며, 어떤 이점이 있고 어떤 단점이 있나요?', '        3. 철근철골콘크리트 구조를 사용한 건물의 장단점을 요약해 주세요.', '        4. 철근철골콘크리트 구조를 사용한 건물의 장점과 단점에 대해 자세히 알려주세요.', '        5. 철근철골콘크리트 구조를 사용한 건물의 장점과 단점을 나열해 주세요.', '        6. 철근철골콘크리트 구조를 사용한 건물의 장단점을 비교해주세요.', '        7. 철근철골콘크리트 구조를 사용한 건물의 장단점을 분석해 주세요.', '        8. 철근철골콘크리트 구조를 사용한 건물의 장점과 단점에 대해 설명해주세요.', '        9. 철근철골콘크리트 구조를 사용한 건물의 장점과 단점을 요약해주세요.', '        10. 철근철골콘크리트 구조를 사용한 건물의 장단점을 평가해주세요.']
#   5%|██████▊                                                                                                                                            | 6/130 [00:50<19:23,  9.39s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 어떤 상황에서 개별 공간이 더 적합한지 알려주세요.', '        2. 어떤 상황에서 오픈 플랜 공간이 더 적합한지 알려주세요.', '        3. 합지벽지의 단점은 무엇인가요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 어떤 상황에서 개별 공간이 더 적합한지 알려주세요.', '        2. 어떤 상황에서 오픈 플랜 공간이 더 적합한지 알려주세요.', '        3. 합지벽지의 단점은 무엇인가요?']
#   5%|███████▉                                                                                                                                           | 7/130 [00:58<17:58,  8.77s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 도배지 들뜸 현상이 발생하는 가장 일반적인 원인은 무엇인가요?', '        2. 도배 시공 시, 도배지 들뜸 현상을 방지하기 위한 방법은 무엇이 있나요?', '        3. 도배지 들뜸 현상을 방지하기 위해, 어떤 종류의 접착제를 사용하는 것이 좋을까요?', '        4. 도배지 들뜸 현상을 방지하기 위해서는, 어떤 종류의 시공 기술을 사용하는 것이 좋을까요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 도배지 들뜸 현상이 발생하는 가장 일반적인 원인은 무엇인가요?', '        2. 도배 시공 시, 도배지 들뜸 현상을 방지할 수 있는 방법은 무엇인가요?', '        3. 도배지 들뜸 현상을 방지하기 위해, 어떤 종류의 접착제를 사용하는 것이 좋을까요?', '        4. 도배지 들뜸 현상을 방지하기 위해, 어떤 종류의 바니쉬를 사용하는 것이 좋을까요?', '        5. 도배지 들뜸 현상을 방지하기 위해, 어떤 종류의 시멘트를 사용하는 것이 좋을까요?']
#   6%|█████████                                                                                                                                          | 8/130 [01:06<17:38,  8.67s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 도배지에 물방울이 떨어졌을 때 어떻게 되나요?', '        2. 도배지에 커피나 음료수 등이  경우 어떻게 해야 하나요?', '        3. 도배지에 잉크가  경우 어떻게 해야 하나요?', '        4. 도배지에 곰팡이가 생겼을 때 어떻게 해야 하나요?', '        5. 도배지에 찢어진 부분이 생겼을 때 어떻게 해야 하나요?', '        6. 도배지에 누런 부분이 생겼을 때 어떻게 해야 하나요?', '        7. 도배지에 껌이나 접착제 같은 것이 묻었을 때 어떻게 해야 하나요?', '        8. 도배지에 빨간색 페인트가  경우 어떻게 해야 하나요?', '        9. 도배지에 검은색 페인트가  경우 어떻게 해야 하나요?', '        10. 도배지에 잉크 지워지는 종이로 지웠는데도 지워지지 않을 때 어떻게 해야 하나요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 도배지에 물방울이 떨어져서 생긴 얼룩의 원인과 해결 방법은 무엇인가요?', '        2. 도배지에 음식물이나 음료수가 묻어서 생긴 얼룩의 원인과 해결 방법은 무엇인가요?', '        3. 도배지에 잉크나 물감이 묻어서 생긴 얼룩의 원인과 해결 방법은 무엇인가요?', '        4. 도배지에 먼지나 이물질이 붙어서 생긴 얼룩의 원인과 해결 방법은 무엇인가요?', '        5. 도배지에 곰팡이가 생긴 얼룩의 원인과 해결 방법은 무엇인가요?']
#   7%|██████████▏                                                                                                                                        | 9/130 [01:19<20:20, 10.08s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 고층 건물의 철골구조의 장점은 무엇인가요?', '        2. 고층 건물의 철근콘크리트구조와 철골구조 중 어떤 것이 더 우수한가요?', '        3. 고층 건물의 철골구조는 어떻게 시공되는 건가요?', '        4. 고층 건물의 철골구조에 사용되는 철재의 종류는 무엇인가요?', '        5. 고층 건물의 철골구조는 내화성이 뛰어난가요?', '        6. 고층 건물의 철골구조는 지진에 강한가요?', '        7. 고층 건물의 철골구조는 유지보수가 쉽나요?', '        8. 고층 건물의 철골구조는 비용이 많이 드나요?', '        9. 고층 건물의 철골구조는 어떤 단점이 있나요?', '        10. 고층 건물의 철골구조에 대해 자세히 알려주실 수 있나요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 고층 건물의 철골 구조의 장단점은 무엇인가요?', '        2. 고층 건물의 철골 구조의 안정성은 어떻게 확보하나요?', '        3. 고층 건물의 철골 구조를 설계할 때 고려해야 할 사항은 무엇인가요?', '        4. 고층 건물의 철골 구조의 내구성에 대해 알고 싶습니다.', '        5. 고층 건물의 철골 구조의 시공 과정은 어떻게 되나요?']
#   8%|███████████▏                                                                                                                                      | 10/130 [01:30<20:26, 10.22s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 유성페인트가 환경에 미치는 영향은 무엇인가요?', '        2. 유성페인트 사용시 주의사항은 무엇인가요?', '        3. 유성페인트 사용시 환경오염을 줄이기 위해 어떤 방법을 사용할 수 있나요?', '        4. 유성페인트 사용시 환경에 대한 대책은 어떻게 세워야 하나요?', '        5. 유성페인트 사용시 환경오염을 방지하기 위한 기술이나 방법은 무엇이 있나요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 유성페인트가 환경에 미치는 영향은 무엇인가요?', '        2. 유성페인트의 환경 오염 사례를 들어주세요.', '        3. 유성페인트로 인한 환경문제는 어떤 것이 있나요?', '        4. 유성페인트의 환경오염 문제점을 구체적으로 설명해주세요.', '        5. 유성페인트가 환경에 미치는 부정적인 영향을 알려주세요.', '        6. 유성페인트의 환경 파괴 사례를 알려주세요.', '        7. 유성페인트로 인해 발생하는 환경 문제는 어떤 것들이 있나요?', '        8. 유성페인트의 환경문제에 대해 자세히 설명해주세요.', '        9. 유성페인트의 환경 오염 문제를 구체적으로 알려주세요.', '        10. 유성페인트로 인한 환경 피해 사례를 알려주세요.']
#   8%|████████████▎                                                                                                                                     | 11/130 [01:44<22:26, 11.31s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 훼손과 오염의 차이점은 무엇인가요?', '        2. 부실 시공으로 인해 타공 하자가 발생할 가능성이 있나요?', '        3. 훼손과 오염을 방지하려면 어떻게 해야 하나요?', '        4. 타공 하자를 방지하려면 어떻게 해야 하나요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 훼손과 오염의 차이점은 무엇인가요?', '        2. 부실 시공으로 인해 타공 하자가 발생할 가능성이 있나요?', '        3. 훼손과 오염을 방지하기 위해 어떤 방법을 사용할 수 있나요?', '        4. 부실 시공을 방지하기 위해 어떤 방법을 사용할 수 있나요?']
#   9%|█████████████▍                                                                                                                                    | 12/130 [01:54<21:34, 10.97s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 철근의 재질은 무엇인가요?', '        2. 철근의 종류는 어떤 것이 있나요?', '        3. 철근의 특성은 무엇인가요?', '        4. 철근의 규격은 어떻게 되나요?', '        5. 철근의 표면처리 방법은 무엇인가요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 철근의 재질은 무엇인가요?', '        2. 철근의 종류는 어떤 것이 있나요?', '        3. 철근의 특징은 무엇인가요?', '        4. 철근의 규격은 어떻게 되나요?', '        5. 철근의 크기는 어떻게 되나요?', '        6. 철근의 사양은 어떻게 되나요?', '        7. 철근의 재료는 어떤 것이 사용되나요?', '        8. 철근의 성분은 어떤 것이 사용되나요?']
#  10%|██████████████▌                                                                                                                                   | 13/130 [02:01<19:02,  9.76s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. What is the difference between fire-resistant wallpaper and silk wallpaper and bonded wallpaper?', '        2. How does fire-resistant wallpaper differ from silk wallpaper and bonded wallpaper?', '        3. Can you explain the differences between fire-resistant wallpaper, silk wallpaper, and bonded wallpaper?', '        4. What are the characteristics of fire-resistant wallpaper that differentiate it from silk wallpaper and bonded wallpaper?', '        5. How does fire-resistant wallpaper compare to silk wallpaper and bonded wallpaper in terms of differences?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 방염벽지, 실크벽지, 합지벽지의 차이점이 무엇인가요?', '        2. 방염벽지와 실크벽지 중 어떤 것이 더 좋나요?', '        3. 합지벽지와 실크벽지 중 어떤 것이 더 좋나요?', '        4. 방염벽지는 왜 그렇게 비싼가요?', '        5. 실크벽지는 어떤 특징이 있나요?', '        6. 합지벽지는 어떤 특징이 있나요?', '        7. 방염벽지와 실크벽지 중 어떤 것이 더 나은 선택인가요?', '        8. 방염벽지와 합지벽지 중 어떤 것이 더 나은 선택인가요?', '        9. 방염벽지와 실크벽지 중 어떤 것을 선택하는 것이 좋을까요?', '        10. 방염벽지와 합지벽지 중 어떤 것을 선택하는 것이 좋을까요?']
#  11%|███████████████▋                                                                                                                                  | 14/130 [02:11<19:13,  9.95s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 도배지에 곰팡이가 생겼을 때 높은 습도가 원인인 경우, 습기 관리는 어떻게 해야 할까요?', '        2. 도배지에 곰팡이가 생겼을 때, 습기 관리에 대한 구체적인 방법은 무엇이 있을까요?', '        3. 도배지에 곰팡이가 생긴 경우, 습기 관리의 중요성에 대해 알고 싶습니다.', '        4. 도배지에 곰팡이가 생겼을 때, 습기 관리의 필요성을 알려주세요.', '        5. 도배지에 곰팡이가 생겼을 때, 습기 관리를 어떻게 해야 하는지 알려주세요.']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 도배지에 곰팡이가 생겼을 때 높은 습도가 원인인 경우, 습기 관리는 어떻게 해야 할까요?', '        2. 도배지에 곰팡이가 생긴 경우, 습기 관리 방법에 대해 알고 싶습니다.', '        3. 도배지에 곰팡이가 생긴 경우, 습기 관리를 어떻게 해야 할까요?', '        4. 도배지에 곰팡이가 생겼을 때, 습기 관리에 대한 방법을 알려주세요.', '        5. 도배지에 곰팡이가 생겼을 때, 습기 관리는 어떻게 해야 할까요?']
#  12%|████████████████▊                                                                                                                                 | 15/130 [02:21<19:08,  9.99s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 롱브릭타일이 어떤 종류의 타일인지 설명해주세요.', '        2. 페인트 상도재의 역할과 사용 방법에 대해 자세히 알려주세요.']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 롱브릭타일이 어떤 타일인지 설명해주세요.', '        2. 페인트 상도재의 역할과 사용 방법에 대해 알려주세요.']
#  12%|█████████████████▉                                                                                                                                | 16/130 [02:29<17:23,  9.15s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 준불연재료는 무엇인가요?', '        2. 유성페인트 사용 시 부작용은 어떤 것이 있나요?', '        3. 준불연재료와 유성페인트의 차이점은 무엇인가요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 준불연재료는 무엇인가요?', '        2. 유성페인트를 사용하는 것에 대한 부작용은 무엇인가요?', '        3. 준불연재료와 유성페인트의 차이점은 무엇인가요?']
#  13%|███████████████████                                                                                                                               | 17/130 [02:36<16:22,  8.69s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 환경 요인으로 인해 몰딩 수정이 필요한 경우가 있나요?', '        2. 반점이 생긴지 1년 이내인 하자에 대해서는 어떻게 보수 작업을 해야 하나요?', '        3. 몰딩 수정을 유발하는 환경 요인은 무엇인가요?', '        4. 반점이 생긴지 1년 이내인 하자에 대한 보수 작업은 어떻게 해야 하나요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 환경 요인으로 인해 몰딩 수정이 발생하는 요인은 무엇인가요?', '        2. 반점이 생긴지 1년 이내인 하자에 대한 보수작업은 어떻게 진행해야 하나요?', '        3. 몰딩 수정을 유발하는 환경 요인을 예방하려면 어떻게 해야 하나요?', '        4. 반점이 생긴지 1년 이내인 하자를 방지하려면 어떻게 해야 하나요?']
#  14%|████████████████████▏                                                                                                                             | 18/130 [02:44<15:47,  8.46s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 타공 불량이 생기는 원인은 무엇인가요?', '        2. 타공 불량이 생겼을 때 어떻게 해야 하나요?', '        3. 타공 불량이 생긴 경우, 어떤 해결 방법이 있나요?', '        4. 타공 불량이 생겼을 때, 어떤 조치를 취해야 하나요?', '        5. 타공 불량이 생겼을 때, 어떤 처리가 필요하나요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 타공 불량이 발생하는 원인은 무엇인가요?', '        2. 타공 불량이 발생하면 어떻게 해결해야 하나요?', '        3. 타공 불량이 발생한 경우, 어떤 조치를 취해야 하나요?', '        4. 타공 불량이 생겼을 때, 어떤 방법을 시도해 볼 수 있나요?', '        5. 타공 불량이 생겼을 때, 어떤 절차를 따라야 하나요?']
#  15%|█████████████████████▎                                                                                                                            | 19/130 [02:52<15:32,  8.40s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 다이닝 룸을 더 고급스럽게 꾸미는 방법은 무엇인가요?', '        2. 아레카 야자를 키우는 것이 어떤 이점이 있나요?', '        3. 다이닝 룸 장식을 개선하는 데 아레카 야자를 활용할 수 있는 방법은 무엇인가요?', '        4. 아레카 야자와 다이닝 룸 장식의 연관성은 무엇인가요?', '        5. 아레카 야자를 이용해 고급스러운 다이닝 룸을 만드는 방법은 무엇인가요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 다이닝 룸을 더 고급스럽게 꾸미는 방법은 무엇인가요?', '        2. 아레카 야자를 키우는 것이 어떤 이점이 있나요?', '        3. 다이닝 룸 장식을 개선하는 데 아레카 야자를 활용할 수 있는 방법은 무엇인가요?']
#  15%|██████████████████████▍                                                                                                                           | 20/130 [03:04<17:11,  9.38s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 습도가 높아서 석고수정이 일어나는 건가요? ', '        2. 피스 하자는 어떤 현상인가요? ', '        3. 석고 수정과 관련된 문제인가요? ', '        4. 습도가 높아서 석고수정이 일어날 수 있는지요? ', '        5. 석고수정과 관련하여 습도가 영향을 미치는지요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 습도가 높아서 석고수정이 발생하나요?', '        2. 또한, 피스 하자가 무엇인지 자세히 설명해 주실 수 있나요?']
#  16%|███████████████████████▌                                                                                                                          | 21/130 [03:13<16:36,  9.14s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 공동주택의 실내 공기질을 측정할 때, 어떤 층에서 샘플을 채취하는 것이 가장 적절한가요?', '        2. 공동주택의 실내 공기질을 측정할 때, 어떤 층에서 샘플을 채취하는 것이 가장 적합한가요?', '        3. 공동주택의 실내 공기질을 측정할 때, 어떤 층에서 샘플을 채취하는 것이 가장 좋은 방법인가요?', '        4. 공동주택의 실내 공기질을 측정할 때, 어떤 층에서 샘플을 채취하는 것이 가장 효과적인가요?', '        5. 공동주택의 실내 공기질을 측정할 때, 어떤 층에서 샘플을 채취하는 것이 가장 바람직한가요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 공동주택의 실내 공기질을 측정할 때, 어떤 층에서 샘플을 채취하는 것이 가장 적절한가요?', '        2. 공동주택의 실내 공기질을 측정할 때, 어떤 층에서 샘플을 채취하는 것이 가장 적절한가요?', '        3. 공동주택의 실내 공기질을 측정할 때, 어떤 층에서 샘플을 채취하는 것이 가장 적절한가요?', '        4. 공동주택의 실내 공기질을 측정할 때, 어떤 층에서 샘플을 채취하는 것이 가장 적절한가요?', '        5. 공동주택의 실내 공기질을 측정할 때, 어떤 층에서 샘플을 채취하는 것이 가장 적절한가요?']
#  17%|████████████████████████▋                                                                                                                         | 22/130 [03:24<17:53,  9.94s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 타일 바닥에서 파손된 타일을 교체하려면 어떤 단계가 필요하나요?', '2. 겨울철에 도배 시 주의해야 할 점은 무엇인가요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 파손된 타일을 교체하려면 어떤 단계가 필요하며, 타일 바닥재에서 이를 수행하는 방법은 무엇인가요?', '        2. 겨울철에 도배를 할 때 주의해야 할 점은 무엇이며, 이 시기에 도배를 하는 데 특별히 유용한 팁이나 기술은 무엇인가요?', '        3. 타일 바닥재에서 파손된 타일을 교체하려면 어떤 도구와 재료가 필요한가요?', '        4. 파손된 타일을 교체할 때 발생할 수 있는 문제점과 그에 대한 해결책은 무엇인가요?', '        5. 타일 바닥재에서 파손된 타일을 교체하는 데 걸리는 시간과 비용은 어떻게 되나요?']
# ...
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. How can sheet waterproofing be used to achieve energy savings in buildings?', '        2. What are the energy-saving effects of sheet waterproofing in buildings?', '        3. How does sheet waterproofing contribute to energy savings in buildings?', '        4. What are the benefits of sheet waterproofing for energy efficiency in buildings?', '        5. How can sheet waterproofing help in achieving energy savings in buildings?']
#  95%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎      | 124/130 [20:16<01:00, 10.12s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['Alternative questions:', '        1. 내진설계에서 안정성을 높이기 위한 순서는 무엇인가요?', '        2. 내진구조란 무엇인가요?', '        3. 내진설계를 할 때, 어떤 요소를 가장 먼저 고려해야 하나요?', '        4. 내진설계에서 안정성을 높이기 위한 방법은 무엇이 있나요?', '        5. 내진설계에서 안정성을 높이기 위한 기술적인 방법은 무엇이 있나요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 내진설계에서 안정성을 높이기 위한 순서는 무엇인가요?', '        2. 내진구조란 무엇인가요?']
#  96%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍     | 125/130 [20:23<00:45,  9.07s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 분말 소화기를 사용할 때 주의해야 할 사항은 무엇인가요?', '        2. 아파트 도배 평수를 어떻게 계산해야 하나요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 분말 소화기를 사용할 때 주의해야 할 사항은 무엇인가요?', '        2. 아파트 도배 평수를 어떻게 계산해야 하나요?']
#  97%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌    | 126/130 [20:29<00:33,  8.33s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 압출법 보온판의 가장 큰 장점은 무엇인가요?', '        2. 압출법 보온판의 장점과 단점을 알려주세요.', '        3. 압출법 보온판의 장점을 다른 보온판과 비교해서 설명해주세요.', '        4. 압출법 보온판의 장점을 활용한 실내 인테리어 아이디어가 있나요?', '        5. 압출법 보온판을 사용하면 어떤 이점이 있을까요?', '        6. 압출법 보온판의 장점을 실제 사례와 함께 설명해주세요.', '        7. 압출법 보온판의 장점을 최대한 활용하려면 어떻게 해야 할까요?', '        8. 압출법 보온판의 장점을 극대화할 수 있는 방법이 있나요?', '        9. 압출법 보온판의 장점을 활용한 다양한 인테리어 스타일이 있나요?', '        10. 압출법 보온판의 장점을 활용한 실내 디자인 아이디어가 있나요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 압출법 보온판의 가장 큰 장점은 무엇인가요?', '        2. 압출법 보온판의 장점과 단점을 알려주세요', '        3. 압출법 보온판을 사용하면 어떤 이점이 있나요?', '        4. 압출법 보온판의 특징과 장점을 알려주세요', '        5. 압출법 보온판의 장단점을 알려주세요', '        6. 압출법 보온판의 장점과 단점을 알려주세요', '        7. 압출법 보온판의 장점과 단점을 알려주세요', '        8. 압출법 보온판의 장점과 단점을 알려주세요', '        9. 압출법 보온판의 장점과 단점을 알려주세요', '        10. 압출법 보온판의 장점과 단점을 알려주세요', '        11. 압출법 보온판의 장점과 단점을 알려주세요', '        12. 압출법 보온판의 장점과 단점을 알려주세요', '        13. 압출법 보온판의 장점과 단점을 알려주세요', '        14. 압출법 보온판의 장점과 단점을 알려주세요', '        15. 압출법 보온판의 장점과 단점을 알려주세요', '        16. 압출법 보온판의 장점과 단점을 알려주세요', '        17. 압출법 보온판의 장점과 단점을 알려주세요', '        18. 압출법 보온판의 장점과 단점을 알려주세요', '        19. 압출법 보온판의 장점과 단점을 알려주세요', '        20. 압출법 보온판의 장점과 단점을 알려주세요', '        21. 압출법 보온판의 장점과 단점을 알려주세요', '        22. 압출법 보온판의 장점과 단점을 알려주세요', '        23. 압출법 보온판의 장점과 단점을 알려주세요', '        24. 압출법 보온판의 장점과 단점을 알려주세요', '        25. 압출법 보온판의 장점과 단점을 알려주세요', '        26. 압출법 보온판의 장점과 단점을 알려주세요', '        27. 압출법 보온판의 장점과 단점을 알려주세요', '        28. 압출법 보온판의 장점과 단점을 알려주세요', '        29. 압출법 보온판의 장점과 단점을 알려주세요', '        30. 압출법 보온판의 장점과 단점을 알려주세요', '        31. 압출법 보온판의 장점과 단점을 알려주세요', '        32. 압출법 보온판의 장점과 단점을 알려주세요', '        33. 압출법 보온판의 장점과 단점을 알려주세요', '        34. 압출법 보온판의 장점과 단점을 알려주세요', '        35. 압출법 보온판의 장점과 단점을 알려주세요', '        36. 압출법 보온판의 장점과 단점을 알려주세요', '        37. 압출법 보온판의 장점과 단점을 알려주세요', '        38. 압출법 보온판의 장점과 단점을 알려주세요', '        39. 압출법 보온판의 장점과 단점을 알려주세요', '        40. 압출법 보온판의 장점과 단점을 알려주세요', '        41. 압출법 보온판의 장점과 단점을 알려주세요', '        42. 압출법 보온판의 장점과 단점을 알려주세요', '        43. 압출법 보온판의 장점과 단점을 알려주세요', '        44. 압출법 보온판의 장점과 단점을 알려주세요', '        45. 압출법 보온판의 장점과 단점을 알려주세요', '        46. 압출법 보온판의 장점과 단점을 알려주세요', '        47. 압출법 보온판의 장점과 단점을 알려주세요', '        48. 압출법 보온판의 장점과 단점을 알려주세요', '        49. 압출법 보온판의 장점과 단점을 알려주세요', '        50. 압출법 보온판의 장점과 단점을 알려주세요', '        51. 압출법 보온판의 장점과 단점을 알려주세요', '        5']
#  98%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋   | 127/130 [21:05<00:50, 16.72s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 수성 벽체용 탄성 방수 도료는 어떤 특징을 가지고 있나요?', '        2. 평지붕의 누수 문제를 해결하기 위해 수성 벽체용 탄성 방수 도료를 사용하는 이유는 무엇인가요?', '        3. 평지붕의 누수 문제를 방지하기 위해 수성 벽체용 탄성 방수 도료를 사용하는 것이 어떤 효과를 얻을 수 있나요?', '        4. 수성 벽체용 탄성 방수 도료는 어떻게 사용해야 하는가요?', '        5. 수성 벽체용 탄성 방수 도료의 장점은 무엇인가요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 평지붕의 누수 문제를 방지하기 위해 수성 벽체용 탄성 방수 도료를 사용하는 것이 어떤 장점이 있나요?', '        2. 평지붕의 누수 문제를 방지하기 위해 수성 벽체용 탄성 방수 도료가 사용되는 이유는 무엇인가요?', '        3. 평지붕의 누수 문제를 방지하기 위해 수성 벽체용 탄성 방수 도료가 사용되는 방법은 무엇인가요?', '        4. 평지붕의 누수 문제를 방지하기 위해 수성 벽체용 탄성 방수 도료의 효과는 어떤가요?', '        5. 평지붕의 누수 문제를 방지하기 위해 수성 벽체용 탄성 방수 도료의 장점은 무엇인가요?']
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊  | 128/130 [21:18<00:30, 15.43s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 석고보드에 생기는 곰팡이와 곰팡이 발생의 원인에 대해 설명해주세요.', '        2. 석고보드의 곰팡이를 제거하고 예방하는 방법에 대해 알려주세요.', '        3. 석고보드의 곰팡이 문제를 해결하기 위해 어떤 기술과 재료를 사용하면 좋을까요?', '        4. 석고보드의 곰팡이 문제를 해결하는 데 도움이 되는 전문 업체나 기술자에 대해 소개해주세요.', '        5. 석고보드 곰팡이 문제를 해결하는 데 필요한 비용과 시간은 얼마나 걸릴까요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 석고보드에 발생한 결로가 가장 큰 원인입니다. 석고보드의 결로를 방지하기 위해서는 보온을 철저히 해야합니다.', '        2. 석고보드의 공기중 습도가 높아 발생하는 경우가 많습니다. 이를 해결하기 위해서는 실내 습도를 조절해야 합니다.', '        3. 석고보드의 품질이 좋지 않은 경우에도 석고수정이 발생할 수 있습니다. 이 경우에는 석고보드를 교체해야 합니다.', '        4. 석고보드가 잘못 시공된 경우에도 석고수정이 발생할 수 있습니다. 이 경우에는 석고보드를 다시 시공해야 합니다.']
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉ | 129/130 [21:29<00:14, 14.23s/it]/usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 카페트의 예상 수명은 얼마인가요?', '        2. 오리지널징크의 장점은 무엇인가요?', '        3. 카페트의 예상 수명을 어떻게 늘릴 수 있나요?', '        4. 오리지널징크의 장점을 극대화하려면 어떻게 해야 하나요?']
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# /usr/local/lib/python3.8/dist-packages/transformers/pipelines/base.py:1157: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Both `max_new_tokens` (=1024) and `max_length`(=3000) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# INFO:langchain.retrievers.multi_query:Generated queries: ['1. 카페트의 예상 수명은 얼마인가요?', '        2. 오리지널징크의 장점은 무엇인가요?', '        3. 카페트의 수명이 어떻게 되나요?', '        4. 오리지널징크의 좋은 점은 무엇인가요?']
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 130/130 [21:37<00:00,  9.98s/it]
# CPU times: user 34min 59s, sys: 40.2 s, total: 35min 39s
# Wall time: 21min 37s

# %% [markdown]
# ## 3.2 인코딩

# %%
distinct = "retriever_multiquery_blog"
today_dt = "2024-03-09"
test_nm = f"{today_dt}_{model_nm}_{distinct}.csv"

# %%
import numpy as np
from sentence_transformers import SentenceTransformer
# Embedding Vector 추출에 활용할 모델(distiluse-base-multilingual-cased-v1) 불러오기
model = SentenceTransformer('distiluse-base-multilingual-cased-v1')

# %%
pred_embeddings = model.encode(result)
pred_embeddings.shape
# Out:
# (130, 512)

# %%
submit = pd.read_csv('./dacon_result/sample_submission.csv')
submit.iloc[:,1:] = pred_embeddings
submit.head()
# Out:
#          id     vec_0     vec_1     vec_2     vec_3     vec_4     vec_5  \
# 0  TEST_000  0.056146  0.012225  0.048413 -0.000903  0.065287 -0.023057
# 1  TEST_001  0.040271  0.039443 -0.009193 -0.004355  0.088474 -0.043821
# 2  TEST_002  0.027215 -0.041707 -0.036222 -0.002769  0.125714 -0.042054
# 3  TEST_003 -0.045773  0.021728 -0.000468  0.031362 -0.042158 -0.061704
# 4  TEST_004 -0.030955 -0.004856  0.025146 -0.025958  0.111109  0.010313
#
#       vec_6     vec_7     vec_8  ...   vec_502   vec_503   vec_504   vec_505  \
# 0 -0.037039  0.019635  0.056421  ... -0.018746 -0.032642 -0.010175 -0.031516
# 1  0.004259  0.000764 -0.028205  ... -0.016111 -0.032665  0.019138 -0.032185
# 2 -0.002592 -0.028100  0.046394  ... -0.054712 -0.008952  0.020674 -0.026505
# 3 -0.006765 -0.062369  0.055340  ...  0.006900 -0.019480  0.060088 -0.027113
# 4  0.062251  0.005962 -0.022942  ... -0.006018  0.043498  0.037011  0.046339
#
#     vec_506   vec_507   vec_508   vec_509   vec_510   vec_511
# 0 -0.025673  0.007156  0.044942  0.024686  0.062100  0.009575
# 1 -0.018601  0.052290 -0.007165 -0.008496  0.026450  0.035253
# 2  0.011675  0.021572 -0.040035 -0.016765 -0.036097  0.067451
# 3  0.006861  0.023011 -0.014874  0.026047 -0.030009  0.088995
# 4 -0.010173 -0.021279  0.012555  0.055604  0.021586  0.088097
#
# [5 rows x 513 columns]

# %%
submit.to_csv('./dacon_result/for_submission/submission_'+test_nm, index=False)

# %% [markdown]
# ## 3.2 답변 결과 저장

# %%
# %%time
docs_lst2 = []
for d in docs_lst :
    doc = []
    for x in d :
        doc.append(x.metadata)
    docs_lst2.append(doc)
# Out:
# CPU times: user 148 µs, sys: 18 µs, total: 166 µs
# Wall time: 168 µs

# %%
test['result'] = result
test['rag_docs'] = docs_lst2
test
# Out:
#            id                                                 질문  \
# 0    TEST_000  방청 페인트의 종류에는 어떤 것들이 있는지 알고 계신가요? 또한, 원목사이딩을 사용...
# 1    TEST_001            도배지에 녹은 자국이 발생하는 주된 원인과 그 해결 방법은 무엇인가요?
# 2    TEST_002    큐블럭의 단점을 알려주세요. 또한, 압출법 단열판을 사용하는 것의 장점은 무엇인가요?
# 3    TEST_003  철골구조를 사용하는 고층 건물에서, 단열 효과를 높이기 위한 시공 방법은 무엇이 있...
# 4    TEST_004                   도배지의 완전한 건조를 위해 몇 주 동안 기다려야 하나요?
# ..        ...                                                ...
# 125  TEST_125  분말 소화기를 사용할 때 주의해야 할 사항은 무엇인가요? 그리고 아파트 도배 평수를...
# 126  TEST_126                          압출법 보온판의 가장 큰 장점은 무엇인가요?"
# 127  TEST_127  평지붕의 누수 문제를 방지하기 위해 수성 벽체용 탄성 방수 도료를 사용하는 것이 어...
# 128  TEST_128  석고수정이 발생하는 가장 큰 원인은 무엇인가요? 그리고 이를 해결하는 방법에 대해 ...
# 129  TEST_129     카페트의 기대 수명은 얼마나 될까요? 그리고 오리지널징크의 장점에는 무엇이 있나요?
#
#                                                 result  \
# 0     방청 페인트는 광명단 페인트, 방청산화철 페인트, 알루미늄 페인트, 역청질 페인트...
# 1     도배지에 녹이 묻어나는 주된 이유는 방청제 사용 누락, 제품 불량, 방화문 프레임...
# 2     큐블럭의 단점은 가격이 비싸고 균열이 쉽게 생기며 습기로 인해 하자가 발생할 수 ...
# 3            고층 건물의 외단열 공사 방법에는 비계 설치와 이동식 비계 등이 있습니다.
# 4     도배 후 도배지가 완전히 건조되기까지 최대 일주일이 걸릴 수 있습니다. 그러나 일...
# ..                                                 ...
# 125   분말 소화기를 사용할 때에는 압력계의 눈금 위치를 확인하고, 받침대를 사용하여 부...
# 126   압출법 보온판의 가장 큰 장점은 압축 강도가 높고 시공이 간편하며 내부식성과 내수...
# 127   수성 벽체용 탄성 방수 도료는 우수한 방수 기능을 제공하며, 크랙의 방지와 물세척...
# 128   석고보드 부분 교체(미장보수)의 원인은 도배 시공 후 석고보드를 부분교체하거나, ...
# 129   카페트의 기대 수명은 일반적으로 6년이며, 사용 빈도, 관리 정도, 실내 환경 등...
#
#                                               rag_docs
# 0    [{'source': '질문 : 방청 페인트는 어떤 기능을 가지고 있나요?
#  방청 ...
# 1    [{'source': './rag_data/blog_summary_final.csv...
# 2    [{'source': '질문 : 큐블럭은 어떤 건물 구조물을 만들 때 사용되는 건축...
# 3    [{'source': '질문 : 고층건물의 단열 시공은 어떻게 해야 하나요?
# 답변 ...
# 4    [{'source': '질문 : 도배 후 건조는 얼마나 해야 해?  답변 : 도배 ...
# ..                                                 ...
# 125  [{'source': '질문 : 분말 소화기가 뭐야?
#  분말 소화기는 어떤 용도로 ...
# 126  [{'source': '질문 : 압출법 보온판은 어떤 재료로 만들어지고, 어떤 용도...
# 127  [{'source': '질문 : 수성 방수 도료를 사용하는 것이 왜 중요할까요?
#  ...
# 128  [{'source': './rag_data/blog_summary_final.csv...
# 129  [{'source': '질문 : 카페트는 기대수명이 얼마야?  답변 : 카페트의 기...
#
# [130 rows x 4 columns]

# %%
test['result'].iloc[0]
# Out:
# ' 방청 페인트는 광명단 페인트, 방청산화철 페인트, 알루미늄 페인트, 역청질 페인트, 워시 프라이머, 크롬산아연 페인트, 규산염 페인트 등으로 분류됩니다. 원목사이딩을 사용하는 단점은 가격대가 높고 관리가 어렵고 습기에 민감하여 변형 가능성이 있으며, 색상 변색과 해충 침입에 취약하다는 것입니다.'

# %%
test.to_csv('./dacon_result/'+test_nm, encoding='utf-8-sig', index=False)
